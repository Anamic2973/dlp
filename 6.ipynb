# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
train_dir = r'/content/gdrive/MyDrive/Colab/cifar-10-img/train/'
test_dir = r'/content/gdrive/MyDrive/Colab/cifar-10-img/test/'

# %%
# !ls /content/gdrive/MyDrive/
# Out:
# ls: cannot access '/content/gdrive/MyDrive/': No such file or directory

# %%
data_train
# Out:
# 'cifar-10-img/train'

# %%
# !ls /content/gdrive/MyDrive/Colab/cifar-10-img/train/
# Out:
# ls: cannot access '/content/gdrive/MyDrive/Colab/cifar-10-img/train/': No such file or directory
